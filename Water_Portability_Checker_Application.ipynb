# %%
from tkinter import *
from tkinter import messagebox
import numpy as np
import pickle
parent = Tk()
parent.title('Water Portability Analyser')
parent.geometry("700x500")
with open('model.pkl' , 'rb') as f:
    lr = pickle.load(f)
def fun():
    print(e1)
    t1=float(e1.get())
    t2=float(e2.get())
    t3=float(e3.get())
    t4=float(e4.get())
    t5=float(e5.get())
    t6=float(e6.get())
    t7=float(e7.get())
    t8=float(e8.get())
    t9=float(e9.get())
    
    out=([[t1,t2,t3,t4,t5,t6,t7,t8,t9]])
    ew=lr.predict(out)
    if ew[0]==0:
        messagebox.showinfo("result","The Water is Toxic")
    else:
        messagebox.showinfo("result","The Water is Drinking Quality")

ph = Label(parent,text = "PH").pack() 
e1 = Entry(parent)
e1.pack()
Hardness = Label(parent,text = "Hardness").pack()  
e2 = Entry(parent)
e2.pack()
Solids = Label(parent,text = "Solids").pack() 
e3 = Entry(parent)
e3.pack()
Chloramines = Label(parent,text = "Chloramines").pack()  
e4 = Entry(parent)
e4.pack()
Sulfate = Label(parent,text = "Sulfate").pack()   
e5 = Entry(parent)
e5.pack() 
Conductivity = Label(parent,text = "Conductivity").pack()  
e6 = Entry(parent)
e6.pack() 
Organic_carbon = Label(parent,text = "Organic_carbon").pack()   
e7 = Entry(parent)
e7.pack() 
Trihalomethanes = Label(parent,text = "Trihalomethanes").pack() 
e8 = Entry(parent)
e8.pack() 
Turbidity = Label(parent,text = "Turbidity").pack()   
e9 = Entry(parent)
e9.pack() 
submit = Button(parent,command =fun, text = "Submit").pack()   
parent.mainloop()
